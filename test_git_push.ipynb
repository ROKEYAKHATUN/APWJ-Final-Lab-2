# %% [markdown]
# <a href="https://colab.research.google.com/github/ROKEYAKHATUN/APWJ-Final-Lab-2/blob/main/test_git_push.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello sriti!")
# Out:
# Hello sriti!
